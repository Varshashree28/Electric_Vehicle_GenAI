# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv(r"C:\Users\dell\Desktop\Project Database\Electric vehicle\Electric_Vehicle_Population_Data.csv")

# %%
df=pd.read_csv(r"C:\Users\dell\Desktop\Project Database\Electric vehicle\electric_vehicles_dataset.csv")

# %%
df
# Out:
#       Vehicle_ID Manufacturer                           Model  Year  \
# 0              1        Acura            ZDX (with GM Ultium)  2015
# 1              2  Lamborghini                 Revuelto (PHEV)  2025
# 2              3          NIO                             ET7  2020
# 3              4         Audi                          e-tron  2025
# 4              5        Acura            ZDX (with GM Ultium)  2023
# ...          ...          ...                             ...   ...
# 3017        3018      Ferrari            SF90 Stradale (PHEV)  2018
# 3018        3019     Mahindra  Born Electric (upcoming range)  2019
# 3019        3020     Cadillac                           Lyriq  2021
# 3020        3021     Mahindra                          XUV400  2021
# 3021        3022           MG                    MG4 Electric  2016
#
#                 Battery_Type  Battery_Capacity_kWh  Range_km  \
# 0           Lithium-titanate                  55.8       214
# ...

# %%
df.count()
# Out:
# Vehicle_ID                3022
# Manufacturer              3022
# Model                     3022
# Year                      3022
# Battery_Type              3022
# Battery_Capacity_kWh      3022
# Range_km                  3022
# Charging_Type             3022
# Charge_Time_hr            3022
# Price_USD                 3022
# Color                     3022
# Country_of_Manufacture    3022
# Autonomous_Level          2580
# CO2_Emissions_g_per_km    2430
# Safety_Rating             2685
# Units_Sold_2024           3022
# Warranty_Years            3022
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3022 entries, 0 to 3021
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Vehicle_ID              3022 non-null   int64
#  1   Manufacturer            3022 non-null   object
#  2   Model                   3022 non-null   object
#  3   Year                    3022 non-null   int64
#  4   Battery_Type            3022 non-null   object
#  5   Battery_Capacity_kWh    3022 non-null   float64
#  6   Range_km                3022 non-null   int64
#  7   Charging_Type           3022 non-null   object
#  8   Charge_Time_hr          3022 non-null   float64
#  9   Price_USD               3022 non-null   float64
#  10  Color                   3022 non-null   object
#  11  Country_of_Manufacture  3022 non-null   object
#  12  Autonomous_Level        2580 non-null   float64
#  13  CO2_Emissions_g_per_km  2430 non-null   float64
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Vehicle_ID', 'Manufacturer', 'Model', 'Year', 'Battery_Type',
#        'Battery_Capacity_kWh', 'Range_km', 'Charging_Type', 'Charge_Time_hr',
#        'Price_USD', 'Color', 'Country_of_Manufacture', 'Autonomous_Level',
#        'CO2_Emissions_g_per_km', 'Safety_Rating', 'Units_Sold_2024',
#        'Warranty_Years'],
#       dtype='object')

# %%
data=df[['Charge_Time_hr',
       'Price_USD','Autonomous_Level','Safety_Rating']]

# %%
# HeatMap to dind coorealtion with columns
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=df.drop('Battery_Capacity_kWh',axis=1)
y=df['Battery_Capacity_kWh']

# %%
x
# Out:
#       Vehicle_ID Manufacturer                 Model  Year  \
# 1              2  Lamborghini       Revuelto (PHEV)  2025
# 2              3          NIO                   ET7  2020
# 3              4         Audi                e-tron  2025
# 4              5        Acura  ZDX (with GM Ultium)  2023
# 8              9      Citroen                  ë-C4  2023
# ...          ...          ...                   ...   ...
# 3013        3014      Porsche                Taycan  2019
# 3016        3017   Volkswagen               ID.2all  2015
# 3017        3018      Ferrari  SF90 Stradale (PHEV)  2018
# 3019        3020     Cadillac                 Lyriq  2021
# 3021        3022           MG          MG4 Electric  2016
#
#                 Battery_Type  Range_km                  Charging_Type  \
# 1           Lithium-titanate       212          Vehicle-to-Home (V2H)
# 2                Calcium-ion       235               Level 2 Charging
# ...

# %%
x=df[['Battery_Capacity_kWh','Charge_Time_hr','Price_USD']]
y=df['Battery_Capacity_kWh']

# %%
x
# Out:
#       Battery_Capacity_kWh  Charge_Time_hr  Price_USD
# 1                     90.8             7.3  127131.65
# 2                     64.7             8.9   94347.37
# 3                    120.5            10.5   75615.15
# 4                     51.8             3.6  141046.94
# 8                     33.8            10.2   90919.55
# ...                    ...             ...        ...
# 3013                  22.4             8.4   98898.46
# 3016                  23.5             5.6  142589.43
# 3017                  49.9            11.7   43988.90
# 3019                 136.5             1.1   88218.53
# 3021                  76.2             2.4  148993.26
#
# [1845 rows x 3 columns]

# %%
x.isnull().sum()
# Out:
# Battery_Capacity_kWh    0
# Charge_Time_hr          0
# Price_USD               0
# dtype: int64

# %%
#split dataset into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 2.917442789294766e-27

# %%
#r2 score

from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 1.0
